# %%
import pandas as pd
import numpy as np
import scipy.stats as sts
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfs = []

sec_id = "sber"
date_from = "2020-01-01"
date_to = "2024-10-31"
url = f"https://iss.moex.com/iss/history/engines/stock/markets/shares/boards/tqbr/securities/{sec_id}/candles.html?from={date_from}&till={date_to}"
retrieved = 0
while True:
    df, cursor = pd.read_html(url + f"&start={retrieved}")
    dfs.append(df)
    retrieved += cursor.at[0, "PAGESIZE (int64)"]
    total = cursor.at[0, "TOTAL (int64)"]
    if retrieved >= total:
        break

df = pd.concat(dfs, axis=0, ignore_index=True)
q = pd.to_datetime(df['TRADEDATE (date:10)'])
df
# Out:
#      BOARDID (string:12) TRADEDATE (date:10) SHORTNAME (string:189)  \
# 0                   TQBR          2020-01-03       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1                   TQBR          2020-01-06       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 2                   TQBR          2020-01-08       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 3                   TQBR          2020-01-09       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 4                   TQBR          2020-01-10       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# ...                  ...                 ...                    ...
# 1219                TQBR          2024-10-25       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1220                TQBR          2024-10-28       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1221                TQBR          2024-10-29       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1222                TQBR          2024-10-30       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1223                TQBR          2024-10-31       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
#
#      SECID (string:36)  NUMTRADES (double)  VALUE (double)  OPEN (double)  \
# 0                 SBER               46191    9.165475e+09         255.99
# 1                 SBER               34925    5.646010e+09         254.75
# 2                 SBER               54429    1.048588e+10         253.57
# 3                 SBER               49305    9.936032e+09         259.40
# 4                 SBER               28908    4.864405e+09         257.86
# ...                ...                 ...             ...            ...
# 1219              SBER              201659    2.012604e+10         252.72
# 1220              SBER              166891    1.765287e+10         245.02
# 1221              SBER              147128    1.143009e+10         243.20
# 1222              SBER              106716    9.721007e+09         242.70
# 1223              SBER              128668    1.373775e+10         241.40
#
#       LOW (double)  HIGH (double)  LEGALCLOSEPRICE (double)  ...  \
# 0           253.70         258.19                    255.00  ...
# 1           251.40         254.84                    253.90  ...
# 2           253.03         259.15                    259.15  ...
# 3           257.01         261.76                    257.99  ...
# 4           256.88         259.25                    258.19  ...
# ...            ...            ...                       ...  ...
# 1219        245.70         255.35                    247.27  ...
# 1220        241.61         249.00                    242.80  ...
# 1221        239.88         244.60                    242.80  ...
# 1222        241.11         246.22                    245.10  ...
# 1223        236.23         242.80                    239.26  ...
#
#       MARKETPRICE3 (double)  ADMITTEDQUOTE (double)  MP2VALTRD (double)  \
# 0                    255.65                  255.00        9.165475e+09
# 1                    252.64                  253.90        5.646010e+09
# 2                    256.90                  259.15        1.048588e+10
# 3                    259.23                  257.99        9.936032e+09
# 4                    258.04                  258.19        4.864405e+09
# ...                     ...                     ...                 ...
# 1219                 250.00                     NaN        1.846269e+10
# 1220                 245.68                     NaN        1.603156e+10
# 1221                 242.43                     NaN        1.048114e+10
# 1222                 244.40                     NaN        7.568627e+09
# 1223                 240.41                     NaN        1.107592e+10
#
#       MARKETPRICE3TRADESVALUE (double)  ADMITTEDVALUE (double)  \
# 0                         9.165475e+09            9.165475e+09
# 1                         5.646010e+09            5.646010e+09
# 2                         1.048588e+10            1.048588e+10
# 3                         9.936032e+09            9.936032e+09
# 4                         4.864405e+09            4.864405e+09
# ...                                ...                     ...
# 1219                      1.846269e+10                     NaN
# 1220                      1.603156e+10                     NaN
# 1221                      1.048114e+10                     NaN
# 1222                      7.568627e+09                     NaN
# 1223                      1.107592e+10                     NaN
#
#       WAVAL (double)  TRADINGSESSION (int32)  CURRENCYID (string:9)  \
# 0                NaN                       3                    SUR
# 1                NaN                       3                    SUR
# 2                NaN                       3                    SUR
# 3                NaN                       3                    SUR
# 4                NaN                       3                    SUR
# ...              ...                     ...                    ...
# 1219             0.0                       3                    SUR
# 1220             0.0                       3                    SUR
# 1221             0.0                       3                    SUR
# 1222             0.0                       3                    SUR
# 1223             0.0                       3                    SUR
#
#       TRENDCLSPR (double)  TRADE_SESSION_DATE (date:10)
# 0                    0.10                           NaN
# 1                   -0.43                           NaN
# 2                    2.07                           NaN
# 3                   -0.45                           NaN
# 4                    0.08                           NaN
# ...                   ...                           ...
# 1219                -2.49                           NaN
# 1220                -1.54                           NaN
# 1221                 0.04                           NaN
# 1222                -0.50                           NaN
# 1223                -1.47                           NaN
#
# [1224 rows x 24 columns]

# %%
dfs = []

sec_id = "tcsg"
date_from = "2020-01-01"
date_to = "2025-02-26"
url = f"https://iss.moex.com/iss/history/engines/stock/markets/shares/boards/tqbr/securities/{sec_id}/candles.html?from={date_from}&till={date_to}"

retrieved = 0
while True:
    df, cursor = pd.read_html(url + f"&start={retrieved}")
    dfs.append(df)
    retrieved += cursor.at[0, "PAGESIZE (int64)"]
    total = cursor.at[0, "TOTAL (int64)"]
    if retrieved >= total:
        break

df = pd.concat(dfs, axis=0, ignore_index=True)

# %% [markdown]
# В таблице, спарсенной с сайта Мосбиржи, содержится информация о торгах акций Т-Банка (в прошлом Тинькофф) на каждый день с 1 января 2020 года по 26 февраля 2025 года, за исключением выходных и праздничных дней.
#
# Что содержится в каждой из колонок таблицы?
#
# 0 колонка - индекс
#
# 1 колонка (BOARDID) - идентификатор рынка. У нас это TQBR - основноый рынок акций на Мосбирже.
#
# 2 колонка (TRADEDATE) - дата торгов.
#
# 3 колонка (SHORTNAME) - имя компании (ТКСХолд ао - это ТКС Холдинг, группа, владеющая Т-Банком)
#
# 4 колонка (SECID) - тикер Т-Банка (TCSG)
#
# 5 колонка (NUMTRADES) - количество сделок за день
#
# 6 колонка (VALUE) - денежный объем торгов (цена*количество; суммарная стоимость всех сделок с ценной бумагой за день)
#
# 7 колонка (OPEN) - цена открытия
#
# 8 колонка (LOW) - минимальная цена
#
# 9 колонка (HIGH) - максимальная цена
#
# 10 колонка (LEGALCLOSEPRICE) - официальная цена закрытия
#
# 11 колонка (WAPRICE) - средневзвешенная цена
#
# 12 колонка (CLOSE) - фактическая цена закрытия
#
# 13 колонка (VOLUME) - количество акций, проданных или купленных за день
#
# 14 колонка (MARKETPRICE2) - рыночная цена 2
#
# 15 колонка (MARKETPRICE3) - рыночная цена 3
#
# 16 колонка (ADMITTEDQUOTE) - признаваемая котировка
#
# 17 колонка (MP2VALTRD) - объём сделок для расчёта рыночной цены
#
# 18 колонка (MARKETPRICE3TRADESVALUE) - значение рыночной цены 3 по итогам торгового дня
#
# 19 колонка (ADMITTEDVALUE) -  объём сделок для расчёта признаваемой котировки
#
# 20 колонка (WAVAL) - средневзвешенная стоимость актива, рассчитанная на основе объема торгов
#
# 21 колонка (TRADINGSESSION) - идентификатор торговой сессии
#
# 22 колонка (CURRENCYID) - индкентификатор валюты - рубль.
#
# 23 колонка (TRENDCLSPR) - индикатор тренда, разница между текущей ценой закрытия и предыдущей ценой закрытия, выраженная в процентах

# %%
nulls = df.isnull().sum(axis = 0)
print(nulls)

a = df['TRADEDATE (date:10)'][(df['OPEN (double)'].isnull() == True) | (df['LOW (double)'].isnull() == True) | (df['HIGH (double)'].isnull() == True) | (df['WAPRICE (double)'].isnull() == True) | (df['CLOSE (double)'].isnull() == True) | (df['TRENDCLSPR (double)'].isnull() == True)]
an = a.to_numpy()

b = df['TRADEDATE (date:10)'][(df['ADMITTEDQUOTE (double)'].isnull() == True) | (df['ADMITTEDVALUE (double)'].isnull() == True)]
bn = b.to_numpy()

c = df['TRADEDATE (date:10)'][df['MARKETPRICE2 (double)'].isnull() == True]
cn = c.to_numpy()

d = df['TRADEDATE (date:10)'][df['WAVAL (double)'].isnull() == True]
dn = d.to_numpy()
# Out:
# BOARDID (string:12)                    0
# TRADEDATE (date:10)                    0
# SHORTNAME (string:189)                 0
# SECID (string:36)                      0
# NUMTRADES (double)                     0
# VALUE (double)                         0
# OPEN (double)                         18
# LOW (double)                          18
# HIGH (double)                         18
# LEGALCLOSEPRICE (double)               0
# WAPRICE (double)                      18
# CLOSE (double)                        18
# VOLUME (double)                        0
# MARKETPRICE2 (double)                  7
# MARKETPRICE3 (double)                  0
# ADMITTEDQUOTE (double)               458
# MP2VALTRD (double)                     0
# MARKETPRICE3TRADESVALUE (double)       0
# ADMITTEDVALUE (double)               458
# WAVAL (double)                       115
# TRADINGSESSION (int32)                 0
# CURRENCYID (string:9)                  0
# TRENDCLSPR (double)                   18
# TRADE_SESSION_DATE (date:10)        1224
# dtype: int64

# %%
cond = df['TRADEDATE (date:10)'].isin(a)
df['Были ли торги'] = np.where(cond, 'нет', 'да')
df['Разброс цен'] = df['HIGH (double)'] - df['LOW (double)']
df['Категория по средневзвешенной цене'] = pd.qcut(df['WAPRICE (double)'], q = 3, labels = ['low', 'medium', 'high'])
df['Прирост количества торгуемых акций'] = df['VOLUME (double)'].diff() / df['VOLUME (double)'].shift()
df['Доходность по средневзвешенной цене'] = df['WAPRICE (double)'].diff() / df['WAPRICE (double)'].shift()
df['Прирост количества сделок'] = df['NUMTRADES (double)'].diff() / df['NUMTRADES (double)'].shift()
df
# Out:
#      BOARDID (string:12) TRADEDATE (date:10) SHORTNAME (string:189)  \
# 0                   TQBR          2020-01-03       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1                   TQBR          2020-01-06       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 2                   TQBR          2020-01-08       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 3                   TQBR          2020-01-09       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 4                   TQBR          2020-01-10       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# ...                  ...                 ...                    ...
# 1219                TQBR          2024-10-25       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1220                TQBR          2024-10-28       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1221                TQBR          2024-10-29       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1222                TQBR          2024-10-30       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
# 1223                TQBR          2024-10-31       Ð¡Ð±ÐµÑÐ±Ð°Ð½Ðº
#
#      SECID (string:36)  NUMTRADES (double)  VALUE (double)  OPEN (double)  \
# 0                 SBER               46191    9.165475e+09         255.99
# 1                 SBER               34925    5.646010e+09         254.75
# 2                 SBER               54429    1.048588e+10         253.57
# 3                 SBER               49305    9.936032e+09         259.40
# 4                 SBER               28908    4.864405e+09         257.86
# ...                ...                 ...             ...            ...
# 1219              SBER              201659    2.012604e+10         252.72
# 1220              SBER              166891    1.765287e+10         245.02
# 1221              SBER              147128    1.143009e+10         243.20
# 1222              SBER              106716    9.721007e+09         242.70
# 1223              SBER              128668    1.373775e+10         241.40
#
#       LOW (double)  HIGH (double)  LEGALCLOSEPRICE (double)  ...  \
# 0           253.70         258.19                    255.00  ...
# 1           251.40         254.84                    253.90  ...
# 2           253.03         259.15                    259.15  ...
# 3           257.01         261.76                    257.99  ...
# 4           256.88         259.25                    258.19  ...
# ...            ...            ...                       ...  ...
# 1219        245.70         255.35                    247.27  ...
# 1220        241.61         249.00                    242.80  ...
# 1221        239.88         244.60                    242.80  ...
# 1222        241.11         246.22                    245.10  ...
# 1223        236.23         242.80                    239.26  ...
#
#       TRADINGSESSION (int32)  CURRENCYID (string:9)  TRENDCLSPR (double)  \
# 0                          3                    SUR                 0.10
# 1                          3                    SUR                -0.43
# 2                          3                    SUR                 2.07
# 3                          3                    SUR                -0.45
# 4                          3                    SUR                 0.08
# ...                      ...                    ...                  ...
# 1219                       3                    SUR                -2.49
# 1220                       3                    SUR                -1.54
# 1221                       3                    SUR                 0.04
# 1222                       3                    SUR                -0.50
# 1223                       3                    SUR                -1.47
#
#       TRADE_SESSION_DATE (date:10)  Были ли торги  Разброс цен  \
# 0                              NaN             да         4.49
# 1                              NaN             да         3.44
# 2                              NaN             да         6.12
# 3                              NaN             да         4.75
# 4                              NaN             да         2.37
# ...                            ...            ...          ...
# 1219                           NaN             да         9.65
# 1220                           NaN             да         7.39
# 1221                           NaN             да         4.72
# 1222                           NaN             да         5.11
# 1223                           NaN             да         6.57
#
#       Категория по средневзвешенной цене  Прирост количества торгуемых акций  \
# 0                                 medium                                 NaN
# 1                                 medium                           -0.376648
# 2                                 medium                            0.826414
# 3                                 medium                           -0.060960
# 4                                 medium                           -0.508169
# ...                                  ...                                 ...
# 1219                              medium                            1.801658
# 1220                              medium                           -0.107298
# 1221                              medium                           -0.344816
# 1222                              medium                           -0.155040
# 1223                              medium                            0.438079
#
#       Доходность по средневзвешенной цене  Прирост количества сделок
# 0                                     NaN                        NaN
# 1                               -0.011658                  -0.243900
# 2                                0.016783                   0.558454
# 3                                0.009148                  -0.094141
# 4                               -0.004552                  -0.413690
# ...                                   ...                        ...
# 1219                            -0.008535                   1.076882
# 1220                            -0.017538                  -0.172410
# 1221                            -0.011656                  -0.118419
# 1222                             0.006515                  -0.274672
# 1223                            -0.017289                   0.205705
#
# [1224 rows x 30 columns]

# %%
jk = df.drop(columns = ['BOARDID (string:12)', 'TRADEDATE (date:10)', 'SHORTNAME (string:189)', 'SECID (string:36)', 'WAVAL (double)', 'TRADINGSESSION (int32)', 'CURRENCYID (string:9)', 'TRADE_SESSION_DATE (date:10)', 'Были ли торги', 'Категория по средневзвешенной цене'])
nk = jk.columns
stat = dict()
stat['Показатель'] = ['Среднее', 'Медиана', '25%-ый квантиль', '50%-ый квантиль', '75%-ый квантиль', 'Min', 'Мax', 'STD']
for el in nk:
    stat[el] = [df[el].mean(), df[el].median(), df[el].quantile(q = 0.25), df[el].quantile(q = 0.5), df[el].quantile(q = 0.75), df[el].min(), df[el].max(), df[el].std()]
framestat = pd.DataFrame(stat)
framestat
# Out:
#         Показатель  NUMTRADES (double)  VALUE (double)  OPEN (double)  \
# 0          Среднее        1.126949e+05    1.420012e+10     240.891045
# 1          Медиана        9.450300e+04    1.093446e+10     257.830000
# 2  25%-ый квантиль        6.814725e+04    7.287915e+09     198.867500
# 3  50%-ый квантиль        9.450300e+04    1.093446e+10     257.830000
# 4  75%-ый квантиль        1.276870e+05    1.673369e+10     289.160000
# 5              Min        0.000000e+00    0.000000e+00      96.550000
# 6              Мax        1.559658e+06    2.385837e+11     385.880000
# 7              STD        9.583588e+04    1.419806e+10      65.806013
#
#    LOW (double)  HIGH (double)  LEGALCLOSEPRICE (double)  WAPRICE (double)  \
# 0     237.74757     243.589461                239.324338        240.693375
# 1     254.72000     260.475000                256.820000        257.305000
# 2     195.07500     203.887500                195.645000        199.517500
# 3     254.72000     260.475000                256.820000        257.305000
# 4     285.90750     291.887500                288.337500        288.802500
# 5      89.59000     106.770000                103.830000        103.010000
# 6     376.72000     388.110000                387.000000        383.410000
# 7      65.64970      65.880603                 66.516742         65.751251
#
#    CLOSE (double)  VOLUME (double)  ...  MARKETPRICE3 (double)  \
# 0      240.809909     6.160184e+07  ...             239.276773
# 1      257.605000     4.731510e+07  ...             256.865000
# 2      200.342500     3.164606e+07  ...             194.917500
# 3      257.605000     4.731510e+07  ...             256.865000
# 4      288.747500     7.229150e+07  ...             288.502500
# 5      101.500000     0.000000e+00  ...             102.820000
# 6      387.600000     1.084508e+09  ...             383.260000
# 7       65.765631     6.525424e+07  ...              66.491534
#
#    ADMITTEDQUOTE (double)  MP2VALTRD (double)  \
# 0              226.442128        1.378941e+10
# 1              229.445000        1.007960e+10
# 2              139.587500        6.727398e+09
# 3              229.445000        1.007960e+10
# 4              288.890000        1.544436e+10
# 5              103.830000        0.000000e+00
# 6              387.000000        4.070000e+11
# 7               74.910073        1.824565e+10
#
#    MARKETPRICE3TRADESVALUE (double)  ADMITTEDVALUE (double)  \
# 0                      1.271527e+10            1.613488e+10
# 1                      9.935810e+09            1.170235e+10
# 2                      6.655571e+09            7.579413e+09
# 3                      9.935810e+09            1.170235e+10
# 4                      1.512628e+10            1.783043e+10
# 5                      5.675900e+05            0.000000e+00
# 6                      1.653794e+11            4.070000e+11
# 7                      1.126149e+10            2.225942e+10
#
#    TRENDCLSPR (double)  Разброс цен  Прирост количества торгуемых акций  \
# 0             0.025158     5.841891                                 inf
# 1             0.045000     4.620000                           -0.051889
# 2            -0.810000     3.260000                           -0.268026
# 3             0.045000     4.620000                           -0.051889
# 4             1.000000     6.907500                            0.314683
# 5           -36.610000     0.720000                           -1.000000
# 6            12.900000    97.950000                                 inf
# 7             2.396023     5.256652                                 NaN
#
#    Доходность по средневзвешенной цене  Прирост количества сделок
# 0                             0.000476                        inf
# 1                             0.000803                  -0.023838
# 2                            -0.007205                  -0.219818
# 3                             0.000803                  -0.023838
# 4                             0.008424                   0.263926
# 5                            -0.137807                  -1.000000
# 6                             0.102363                        inf
# 7                             0.018336                        NaN
#
# [8 rows x 21 columns]

# %%
jk.corr()
# Out:
#                                      NUMTRADES (double)  VALUE (double)  \
# NUMTRADES (double)                             1.000000        0.890572
# VALUE (double)                                 0.890572        1.000000
# OPEN (double)                                 -0.135726        0.118156
# LOW (double)                                  -0.183724        0.076340
# HIGH (double)                                 -0.115694        0.139151
# LEGALCLOSEPRICE (double)                      -0.126749        0.122299
# WAPRICE (double)                              -0.153859        0.105559
# CLOSE (double)                                -0.153200        0.105565
# VOLUME (double)                                0.954727        0.940721
# MARKETPRICE2 (double)                         -0.137369        0.116231
# MARKETPRICE3 (double)                         -0.124390        0.124607
# ADMITTEDQUOTE (double)                        -0.086149        0.207992
# MP2VALTRD (double)                             0.458449        0.549283
# MARKETPRICE3TRADESVALUE (double)               0.855023        0.985411
# ADMITTEDVALUE (double)                         0.425438        0.510635
# TRENDCLSPR (double)                           -0.279122       -0.182520
# Разброс цен                                    0.844533        0.790549
# Прирост количества торгуемых акций             0.319469        0.282669
# Доходность по средневзвешенной цене           -0.195011       -0.169893
# Прирост количества сделок                      0.349084        0.291560
#
#                                      OPEN (double)  LOW (double)  \
# NUMTRADES (double)                       -0.135726     -0.183724
# VALUE (double)                            0.118156      0.076340
# OPEN (double)                             1.000000      0.997627
# LOW (double)                              0.997627      1.000000
# HIGH (double)                             0.998959      0.996812
# LEGALCLOSEPRICE (double)                  0.997442      0.998923
# WAPRICE (double)                          0.998612      0.999288
# CLOSE (double)                            0.997497      0.998717
# VOLUME (double)                          -0.131799     -0.178116
# MARKETPRICE2 (double)                     0.998583      0.999260
# MARKETPRICE3 (double)                     0.998583      0.999260
# ADMITTEDQUOTE (double)                    0.997185      0.998868
# MP2VALTRD (double)                        0.119196      0.079923
# MARKETPRICE3TRADESVALUE (double)          0.119196      0.079923
# ADMITTEDVALUE (double)                    0.225043      0.183101
# TRENDCLSPR (double)                      -0.032748      0.016044
# Разброс цен                               0.060509      0.003967
# Прирост количества торгуемых акций       -0.008902     -0.019549
# Доходность по средневзвешенной цене      -0.027205      0.002298
# Прирост количества сделок                 0.003510     -0.009235
#
#                                      HIGH (double)  LEGALCLOSEPRICE (double)  \
# NUMTRADES (double)                       -0.115694                 -0.126749
# VALUE (double)                            0.139151                  0.122299
# OPEN (double)                             0.998959                  0.997442
# LOW (double)                              0.996812                  0.998923
# HIGH (double)                             1.000000                  0.998232
# LEGALCLOSEPRICE (double)                  0.998232                  1.000000
# WAPRICE (double)                          0.998914                  0.999633
# CLOSE (double)                            0.998412                  0.999805
# VOLUME (double)                          -0.111221                 -0.126274
# MARKETPRICE2 (double)                     0.998849                  0.999312
# MARKETPRICE3 (double)                     0.998849                  0.999588
# ADMITTEDQUOTE (double)                    0.998011                  1.000000
# MP2VALTRD (double)                        0.141690                 -0.008430
# MARKETPRICE3TRADESVALUE (double)          0.141690                  0.128233
# ADMITTEDVALUE (double)                    0.246100                  0.048546
# TRENDCLSPR (double)                      -0.011256                  0.029056
# Разброс цен                               0.083744                  0.035214
# Прирост количества торгуемых акций        0.002135                 -0.006046
# Доходность по средневзвешенной цене      -0.011277                  0.009757
# Прирост количества сделок                 0.012807                  0.003326
#
#                                      WAPRICE (double)  CLOSE (double)  \
# NUMTRADES (double)                          -0.153859       -0.153200
# VALUE (double)                               0.105559        0.105565
# OPEN (double)                                0.998612        0.997497
# LOW (double)                                 0.999288        0.998717
# HIGH (double)                                0.998914        0.998412
# LEGALCLOSEPRICE (double)                     0.999633        0.999805
# WAPRICE (double)                             1.000000        0.999531
# CLOSE (double)                               0.999531        1.000000
# VOLUME (double)                             -0.148334       -0.147174
# MARKETPRICE2 (double)                        0.999983        0.999408
# MARKETPRICE3 (double)                        0.999983        0.999408
# ADMITTEDQUOTE (double)                       0.999616        0.999816
# MP2VALTRD (double)                           0.108950        0.109405
# MARKETPRICE3TRADESVALUE (double)             0.108950        0.109405
# ADMITTEDVALUE (double)                       0.212676        0.211811
# TRENDCLSPR (double)                          0.011109        0.029073
# Разброс цен                                  0.039219        0.040048
# Прирост количества торгуемых акций          -0.008233       -0.007242
# Доходность по средневзвешенной цене         -0.000464        0.010966
# Прирост количества сделок                    0.001875        0.001555
#
#                                      VOLUME (double)  MARKETPRICE2 (double)  \
# NUMTRADES (double)                          0.954727              -0.137369
# VALUE (double)                              0.940721               0.116231
# OPEN (double)                              -0.131799               0.998583
# LOW (double)                               -0.178116               0.999260
# HIGH (double)                              -0.111221               0.998849
# LEGALCLOSEPRICE (double)                   -0.126274               0.999312
# WAPRICE (double)                           -0.148334               0.999983
# CLOSE (double)                             -0.147174               0.999408
# VOLUME (double)                             1.000000              -0.135113
# MARKETPRICE2 (double)                      -0.135113               1.000000
# MARKETPRICE3 (double)                      -0.124586               0.999723
# ADMITTEDQUOTE (double)                     -0.042942               0.999237
# MP2VALTRD (double)                          0.511112              -0.002655
# MARKETPRICE3TRADESVALUE (double)            0.918210               0.120851
# ADMITTEDVALUE (double)                      0.469081               0.055817
# TRENDCLSPR (double)                        -0.240811               0.010571
# Разброс цен                                 0.830554               0.038749
# Прирост количества торгуемых акций          0.294909              -0.005705
# Доходность по средневзвешенной цене        -0.157060              -0.001652
# Прирост количества сделок                   0.300495               0.005116
#
#                                      MARKETPRICE3 (double)  \
# NUMTRADES (double)                               -0.124390
# VALUE (double)                                    0.124607
# OPEN (double)                                     0.998583
# LOW (double)                                      0.999260
# HIGH (double)                                     0.998849
# LEGALCLOSEPRICE (double)                          0.999588
# WAPRICE (double)                                  0.999983
# CLOSE (double)                                    0.999408
# VOLUME (double)                                  -0.124586
# MARKETPRICE2 (double)                             0.999723
# MARKETPRICE3 (double)                             1.000000
# ADMITTEDQUOTE (double)                            0.999584
# MP2VALTRD (double)                               -0.007101
# MARKETPRICE3TRADESVALUE (double)                  0.130323
# ADMITTEDVALUE (double)                            0.050364
# TRENDCLSPR (double)                               0.010571
# Разброс цен                                       0.038749
# Прирост количества торгуемых акций               -0.005989
# Доходность по средневзвешенной цене              -0.001652
# Прирост количества сделок                         0.004759
#
#                                      ADMITTEDQUOTE (double)  \
# NUMTRADES (double)                                -0.086149
# VALUE (double)                                     0.207992
# OPEN (double)                                      0.997185
# LOW (double)                                       0.998868
# HIGH (double)                                      0.998011
# LEGALCLOSEPRICE (double)                           1.000000
# WAPRICE (double)                                   0.999616
# CLOSE (double)                                     0.999816
# VOLUME (double)                                   -0.042942
# MARKETPRICE2 (double)                              0.999237
# MARKETPRICE3 (double)                              0.999584
# ADMITTEDQUOTE (double)                             1.000000
# MP2VALTRD (double)                                 0.048546
# MARKETPRICE3TRADESVALUE (double)                   0.232161
# ADMITTEDVALUE (double)                             0.048546
# TRENDCLSPR (double)                                0.042620
# Разброс цен                                        0.094694
# Прирост количества торгуемых акций                -0.019088
# Доходность по средневзвешенной цене                0.023271
# Прирост количества сделок                         -0.018409
#
#                                      MP2VALTRD (double)  \
# NUMTRADES (double)                             0.458449
# VALUE (double)                                 0.549283
# OPEN (double)                                  0.119196
# LOW (double)                                   0.079923
# HIGH (double)                                  0.141690
# LEGALCLOSEPRICE (double)                      -0.008430
# WAPRICE (double)                               0.108950
# CLOSE (double)                                 0.109405
# VOLUME (double)                                0.511112
# MARKETPRICE2 (double)                         -0.002655
# MARKETPRICE3 (double)                         -0.007101
# ADMITTEDQUOTE (double)                         0.048546
# MP2VALTRD (double)                             1.000000
# MARKETPRICE3TRADESVALUE (double)               0.550698
# ADMITTEDVALUE (double)                         1.000000
# TRENDCLSPR (double)                           -0.148203
# Разброс цен                                    0.777624
# Прирост количества торгуемых акций             0.259926
# Доходность по средневзвешенной цене           -0.141477
# Прирост количества сделок                      0.261909
#
#                                      MARKETPRICE3TRADESVALUE (double)  \
# NUMTRADES (double)                                           0.855023
# VALUE (double)                                               0.985411
# OPEN (double)                                                0.119196
# LOW (double)                                                 0.079923
# HIGH (double)                                                0.141690
# LEGALCLOSEPRICE (double)                                     0.128233
# WAPRICE (double)                                             0.108950
# CLOSE (double)                                               0.109405
# VOLUME (double)                                              0.918210
# MARKETPRICE2 (double)                                        0.120851
# MARKETPRICE3 (double)                                        0.130323
# ADMITTEDQUOTE (double)                                       0.232161
# MP2VALTRD (double)                                           0.550698
# MARKETPRICE3TRADESVALUE (double)                             1.000000
# ADMITTEDVALUE (double)                                       0.506221
# TRENDCLSPR (double)                                         -0.148203
# Разброс цен                                                  0.777624
# Прирост количества торгуемых акций                           0.297164
# Доходность по средневзвешенной цене                         -0.141477
# Прирост количества сделок                                    0.305776
#
#                                      ADMITTEDVALUE (double)  \
# NUMTRADES (double)                                 0.425438
# VALUE (double)                                     0.510635
# OPEN (double)                                      0.225043
# LOW (double)                                       0.183101
# HIGH (double)                                      0.246100
# LEGALCLOSEPRICE (double)                           0.048546
# WAPRICE (double)                                   0.212676
# CLOSE (double)                                     0.211811
# VOLUME (double)                                    0.469081
# MARKETPRICE2 (double)                              0.055817
# MARKETPRICE3 (double)                              0.050364
# ADMITTEDQUOTE (double)                             0.048546
# MP2VALTRD (double)                                 1.000000
# MARKETPRICE3TRADESVALUE (double)                   0.506221
# ADMITTEDVALUE (double)                             1.000000
# TRENDCLSPR (double)                               -0.183326
# Разброс цен                                        0.770233
# Прирост количества торгуемых акций                 0.208046
# Доходность по средневзвешенной цене               -0.179533
# Прирост количества сделок                          0.230288
#
#                                      TRENDCLSPR (double)  Разброс цен  \
# NUMTRADES (double)                             -0.279122     0.844533
# VALUE (double)                                 -0.182520     0.790549
# OPEN (double)                                  -0.032748     0.060509
# LOW (double)                                    0.016044     0.003967
# HIGH (double)                                  -0.011256     0.083744
# LEGALCLOSEPRICE (double)                        0.029056     0.035214
# WAPRICE (double)                                0.011109     0.039219
# CLOSE (double)                                  0.029073     0.040048
# VOLUME (double)                                -0.240811     0.830554
# MARKETPRICE2 (double)                           0.010571     0.038749
# MARKETPRICE3 (double)                           0.010571     0.038749
# ADMITTEDQUOTE (double)                          0.042620     0.094694
# MP2VALTRD (double)                             -0.148203     0.777624
# MARKETPRICE3TRADESVALUE (double)               -0.148203     0.777624
# ADMITTEDVALUE (double)                         -0.183326     0.770233
# TRENDCLSPR (double)                             1.000000    -0.341437
# Разброс цен                                    -0.341437     1.000000
# Прирост количества торгуемых акций              0.022707     0.315588
# Доходность по средневзвешенной цене             0.765312    -0.198404
# Прирост количества сделок                      -0.049938     0.321682
#
#                                      Прирост количества торгуемых акций  \
# NUMTRADES (double)                                             0.319469
# VALUE (double)                                                 0.282669
# OPEN (double)                                                 -0.008902
# LOW (double)                                                  -0.019549
# HIGH (double)                                                  0.002135
# LEGALCLOSEPRICE (double)                                      -0.006046
# WAPRICE (double)                                              -0.008233
# CLOSE (double)                                                -0.007242
# VOLUME (double)                                                0.294909
# MARKETPRICE2 (double)                                         -0.005705
# MARKETPRICE3 (double)                                         -0.005989
# ADMITTEDQUOTE (double)                                        -0.019088
# MP2VALTRD (double)                                             0.259926
# MARKETPRICE3TRADESVALUE (double)                               0.297164
# ADMITTEDVALUE (double)                                         0.208046
# TRENDCLSPR (double)                                            0.022707
# Разброс цен                                                    0.315588
# Прирост количества торгуемых акций                             1.000000
# Доходность по средневзвешенной цене                           -0.001033
# Прирост количества сделок                                      0.929636
#
#                                      Доходность по средневзвешенной цене  \
# NUMTRADES (double)                                             -0.195011
# VALUE (double)                                                 -0.169893
# OPEN (double)                                                  -0.027205
# LOW (double)                                                    0.002298
# HIGH (double)                                                  -0.011277
# LEGALCLOSEPRICE (double)                                        0.009757
# WAPRICE (double)                                               -0.000464
# CLOSE (double)                                                  0.010966
# VOLUME (double)                                                -0.157060
# MARKETPRICE2 (double)                                          -0.001652
# MARKETPRICE3 (double)                                          -0.001652
# ADMITTEDQUOTE (double)                                          0.023271
# MP2VALTRD (double)                                             -0.141477
# MARKETPRICE3TRADESVALUE (double)                               -0.141477
# ADMITTEDVALUE (double)                                         -0.179533
# TRENDCLSPR (double)                                             0.765312
# Разброс цен                                                    -0.198404
# Прирост количества торгуемых акций                             -0.001033
# Доходность по средневзвешенной цене                             1.000000
# Прирост количества сделок                                      -0.063690
#
#                                      Прирост количества сделок
# NUMTRADES (double)                                    0.349084
# VALUE (double)                                        0.291560
# OPEN (double)                                         0.003510
# LOW (double)                                         -0.009235
# HIGH (double)                                         0.012807
# LEGALCLOSEPRICE (double)                              0.003326
# WAPRICE (double)                                      0.001875
# CLOSE (double)                                        0.001555
# VOLUME (double)                                       0.300495
# MARKETPRICE2 (double)                                 0.005116
# MARKETPRICE3 (double)                                 0.004759
# ADMITTEDQUOTE (double)                               -0.018409
# MP2VALTRD (double)                                    0.261909
# MARKETPRICE3TRADESVALUE (double)                      0.305776
# ADMITTEDVALUE (double)                                0.230288
# TRENDCLSPR (double)                                  -0.049938
# Разброс цен                                           0.321682
# Прирост количества торгуемых акций                    0.929636
# Доходность по средневзвешенной цене                  -0.063690
# Прирост количества сделок                             1.000000

# %%
# import matplotlib.dates as mdates
plt.figure(figsize=(25.6, 4.8))
plt.plot(q, df["NUMTRADES (double)"])
plt.title('Временной ряд динамики торгов акциями Сбера')
plt.xlabel('Даты торгов')
plt.ylabel('Количество проведенных сделок')
plt.show()

# %%
plt.figure(figsize=(12.8, 4.8))
plt.plot(q, df["OPEN (double)"], label="Opening price")
plt.plot(q, df["CLOSE (double)"], label="Closing price")
#plt.plot(df_before_split.index, df_before_split["HIGH (double)"], label="Highest price")
plt.xlabel('Даты торгов')
plt.ylabel('Цена акции')
plt.legend()
plt.show()

# %%
close_open_delta = df["CLOSE (double)"] - df["OPEN (double)"]
plt.figure(figsize=(25.6, 4.8))
plt.plot(q, close_open_delta)
plt.show()

# %%
plt.figure(figsize = (10, 5))

plt.plot(q, df['WAPRICE (double)'])
plt.grid()
plt.title('Динамика средневзвешенной цены акций Сбера по дням')
plt.xlabel('Даты торгов')
plt.ylabel('Средневзвешенная цена акций')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(q, df['LOW (double)'], label = 'LOW')
plt.plot(q, df['HIGH (double)'], label = 'HIGH' )
plt.grid()
plt.legend()
plt.title('Динамика мин. и макс. цены акций Сбера по дням')
plt.xlabel('Даты')
plt.ylabel('Цены акций')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(q, df['Прирост количества торгуемых акций'])
plt.grid()
plt.title('Темпы прироста количества торгуемых акций')
plt.xlabel('Даты')
plt.ylabel('Количество сделок')
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.hist(df['WAPRICE (double)'], bins = 200, edgecolor = 'red')
plt.grid()
plt.title('Гистограмма распределения средневзвешенных цен на акции Сбера')
plt.xlabel('Интервал цен')
plt.ylabel('Количество акций')
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.histplot(df['LEGALCLOSEPRICE (double)'], bins = 200, edgecolor = 'red', kde = True)
plt.grid()
plt.title('Гистограмма распределения официальных цен закрытия на акции Сбера')
plt.xlabel('Интервал цен')
plt.ylabel('Количество акций')
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.histplot(df['Доходность по средневзвешенной цене'], bins = 200, edgecolor = 'red', kde = True)
plt.grid()
plt.title('Гистограмма распределения доходности акций Сбера')
plt.xlabel('Интервалы доходностей')
plt.ylabel('Количество дней')
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.histplot(df['Прирост количества сделок'], bins = 200, edgecolor = 'red', kde = True)
plt.grid()
plt.title('Гистограмма распределения прироста сделок для Сбера')
plt.xlabel('Интервалы прироста сделок')
plt.ylabel('Количество дней')
plt.show()
